# %%
import os
import sys

# %%
# 상위 경로 추가
sys.path.append(os.pardir)

# %%
# 다양한 기능을 모듈로 만들어서 실행
from modules.face_detection import FaceDetection

# %%
# model 경로
# image 경로
# sticker image 경로
model_path = os.getenv('HOME')+'/aiffel/camera_sticker/models/shape_predictor_68_face_landmarks.dat'
image_path = "../data/img.jpg"
sticker_path = '../data/cat-whiskers.png'

# %%
face = FaceDetection(model_path)

# %%
# 이미지 불러오기
image = face.load_image(image_path, False)
sticker = face.load_sticker(sticker_path)

# %%
# 이미지 정보 출력
print(face)
# Out:
# (480, 640, 3) , BGR

# %%
# 바운딩 박스 그리기
bounding_box_image = face.face_bounding_box(image,False)
# Out:
# rectangles[[(354, 280) (1019, 946)]]

# %%
# 랜드마크 찾기
landmark_image = face.face_landmark(image)
# Out:
# The number of dots : 68

# %%
sticker_image = face.attaching_sticker(image, 255, True)

# %% [markdown]
# # 사진 변환

# %%
# 새로운 이미지 불러오기
# 회전
image2 = face.load_image(image_path, False)
rotate_image = face.rotate_image(image2, 45)

# %%
# 밝게
britened_image = face.mod_brightness(image2)

# %%
# zoom
zoom_image = face.paddedzoom(image2, 5)
